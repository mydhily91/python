# %%
#DATA ALIGNMENT
import numpy as np
from pandas import Series, DataFrame
import pandas as pd
from random import randint,random,randrange

# %%
series = Series(np.arange(6),index = ['a','b','c','d','e','f'])
series
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# dtype: int64

# %%
series1 = Series([6,7,8,9,10,11,12],index = ['a','b','c','d','e','f','g'])
series1
# Out:
# a     6
# b     7
# c     8
# d     9
# e    10
# f    11
# g    12
# dtype: int64

# %%
#Adding two series
series.add(series1, fill_value = 6)
# Out:
# a     6.0
# b     8.0
# c    10.0
# d    12.0
# e    14.0
# f    16.0
# g    18.0
# dtype: float64

# %%
series + series1
# Out:
# a     6.0
# b     8.0
# c    10.0
# d    12.0
# e    14.0
# f    16.0
# g     NaN
# dtype: float64

# %%
dataframe = DataFrame(np.arange(16).reshape((4,4)),columns=list('ABCD'), index=['NYC','LA','SF','NJ'])
dataframe
# Out:
#       A   B   C   D
# NYC   0   1   2   3
# LA    4   5   6   7
# SF    8   9  10  11
# NJ   12  13  14  15

# %%
dframe =DataFrame(np.arange(9).reshape((3,3)),columns=list('ABD'), index=['NYC','LA','SF'])
dframe
# Out:
#      A  B  D
# NYC  0  1  2
# LA   3  4  5
# SF   6  7  8

# %%
dataframe.add(dframe,fill_value = 0)
# Out:
#         A     B     C     D
# LA    7.0   9.0   6.0  12.0
# NJ   12.0  13.0  14.0  15.0
# NYC   0.0   2.0   2.0   5.0
# SF   14.0  16.0  10.0  19.0

# %%
series2 = Series(range(0,3),index = ['B','C','A'])
series2
# Out:
# B    0
# C    1
# A    2
# dtype: int64

# %%
#Sorting
series2.sort_index()
# Out:
# A    2
# B    0
# C    1
# dtype: int64

# %%
series2.sort_values()
# Out:
# B    0
# C    1
# A    2
# dtype: int64

# %%
dataframe
# Out:
#       A   B   C   D
# NYC   0   1   2   3
# LA    4   5   6   7
# SF    8   9  10  11
# NJ   12  13  14  15

# %%
dataframe.sum(axis=1)
# Out:
# NYC     6
# LA     22
# SF     38
# NJ     54
# dtype: int64

# %%
#the min method is going to call minimum value in each coloumn
dataframe.min()
# Out:
# A    0
# B    1
# C    2
# D    3
# dtype: int64

# %%
dataframe.min(axis=1)
# Out:
# NYC     0
# LA      4
# SF      8
# NJ     12
# dtype: int64

# %%
#min value and its index
dataframe.idxmin()
# Out:
# A    NYC
# B    NYC
# C    NYC
# D    NYC
# dtype: object

# %%
dataframe.cumsum()
# Out:
#       A   B   C   D
# NYC   0   1   2   3
# LA    4   6   8  10
# SF   12  15  18  21
# NJ   24  28  32  36

# %%
'''
DataFrame.count Counts number of non-NA/null observations.
DataFrame.max Maximum of the values in the object.
DataFrame.min Minimum of the values in the object.
DataFrame.mean Mean of the values.
DataFrame.std Standard deviation of the obersvations.
DataFrame.select_dtypes Subset of a DataFrame including/excluding columns based on their dtype.
'''
dataframe.describe()
# Out:
#                A          B          C          D
# count   4.000000   4.000000   4.000000   4.000000
# mean    6.000000   7.000000   8.000000   9.000000
# std     5.163978   5.163978   5.163978   5.163978
# min     0.000000   1.000000   2.000000   3.000000
# 25%     3.000000   4.000000   5.000000   6.000000
# 50%     6.000000   7.000000   8.000000   9.000000
# 75%     9.000000  10.000000  11.000000  12.000000
# max    12.000000  13.000000  14.000000  15.000000

# %%
import datetime
from pandas_datareader import data, wb
import pandas_datareader as pdr

# %%
prices = pdr.get_data_yahoo(['CVX','XOM','BP'],start = datetime.datetime(2010,1,1),end = datetime.datetime(2013,1,1))['Adj Close']
prices
# Out:
# Symbols            BP        CVX        XOM
# Date
# 2010-01-04  36.332241  55.557301  51.284389
# 2010-01-05  36.590214  55.950813  51.484634
# 2010-01-06  36.780628  55.957851  51.929600
# 2010-01-07  36.768337  55.747028  51.766449
# 2010-01-08  36.854328  55.845425  51.558784
# 2010-01-11  38.015251  56.836235  52.137276
# 2010-01-12  37.775700  56.505962  51.877697
# 2010-01-13  37.959972  56.077297  51.670040
# 2010-01-14  37.916981  55.901638  51.677464
# 2010-01-15  37.861687  55.676762  51.254730
# 2010-01-19  38.279369  55.992981  51.373379
# 2010-01-20  37.505428  54.917831  50.453739
# 2010-01-21  36.590214  53.575615  49.467373
# 2010-01-22  35.545994  52.416126  49.022381
# 2010-01-25  35.963692  52.388027  48.836967
# 2010-01-26  35.926838  52.106915  48.888878
# 2010-01-27  35.662712  51.790703  48.607067
# 2010-01-28  35.214317  51.467449  48.176918
# 2010-01-29  34.471088  50.680416  47.783844
# 2010-02-01  35.152905  51.706379  49.081718
# ...

# %%
#Preview of the data frame it's gone show couple of values of the data frame
prices.head()
# Out:
# Symbols            BP        CVX        XOM
# Date
# 2010-01-04  36.332241  55.557301  51.284389
# 2010-01-05  36.590214  55.950813  51.484634
# 2010-01-06  36.780628  55.957851  51.929600
# 2010-01-07  36.768337  55.747028  51.766449
# 2010-01-08  36.854328  55.845425  51.558784

# %%
prices.tail()
# Out:
# Symbols            BP        CVX        XOM
# Date
# 2012-12-26  28.276445  84.305046  69.614738
# 2012-12-27  28.235739  84.351707  69.446808
# 2012-12-28  27.964369  82.742706  68.039665
# 2012-12-31  28.249310  84.056351  69.198967
# 2013-01-02  28.778463  85.805222  70.925941

# %%
# To know the volume of the data frame
Volume = pdr.get_data_yahoo(['CVX','XOM','BP'],start = datetime.datetime(2010,1,1),end = datetime.datetime(2013,1,1))['Volume']
Volume
# Out:
# Symbols             BP         CVX         XOM
# Date
# 2010-01-04   3956100.0  10173800.0  27809100.0
# 2010-01-05   4109600.0  10593700.0  30174700.0
# 2010-01-06   6227900.0  11014600.0  35044700.0
# 2010-01-07   4431300.0   9626900.0  27192100.0
# 2010-01-08   3786100.0   5624300.0  24891800.0
# 2010-01-11   8227200.0  11916800.0  30685000.0
# 2010-01-12   6126600.0  12175200.0  31496700.0
# 2010-01-13   5686600.0  10842200.0  24884400.0
# 2010-01-14   3330700.0   6721000.0  18630800.0
# 2010-01-15   3596700.0  13482300.0  29411900.0
# 2010-01-19   4914400.0   8722200.0  26081900.0
# 2010-01-20   5410900.0   8703800.0  34629500.0
# 2010-01-21   7184400.0  12573200.0  39114000.0
# 2010-01-22   7297200.0  13825000.0  39085500.0
# 2010-01-25   4039100.0   9129700.0  29305100.0
# 2010-01-26   5684700.0  10558200.0  34083300.0
# 2010-01-27   6025600.0  13373200.0  35723500.0
# 2010-01-28   5003700.0  12828800.0  37349800.0
# 2010-01-29   7643200.0  15265600.0  40880500.0
# ...

# %%
Volume.head()
#this gets amount of the stocks they have 3956100.0	10173800.0	27809100.0 traded
# Out:
# Symbols            BP         CVX         XOM
# Date
# 2010-01-04  3956100.0  10173800.0  27809100.0
# 2010-01-05  4109600.0  10593700.0  30174700.0
# 2010-01-06  6227900.0  11014600.0  35044700.0
# 2010-01-07  4431300.0   9626900.0  27192100.0
# 2010-01-08  3786100.0   5624300.0  24891800.0

# %%
#returns on your stock
returns = prices.pct_change()
returns.head()
# Out:
# Symbols           BP       CVX       XOM
# Date
# 2010-01-04       NaN       NaN       NaN
# 2010-01-05  0.007100  0.007083  0.003905
# 2010-01-06  0.005204  0.000126  0.008643
# 2010-01-07 -0.000334 -0.003768 -0.003142
# 2010-01-08  0.002339  0.001765 -0.004012

# %%
# To get correlation of the stocks
correlation = returns.corr
correlation
# Out:
# <bound method DataFrame.corr of Symbols           BP       CVX       XOM
# Date
# 2010-01-04       NaN       NaN       NaN
# 2010-01-05  0.007100  0.007083  0.003905
# 2010-01-06  0.005204  0.000126  0.008643
# 2010-01-07 -0.000334 -0.003768 -0.003142
# 2010-01-08  0.002339  0.001765 -0.004012
# 2010-01-11  0.031500  0.017742  0.011220
# 2010-01-12 -0.006301 -0.005811 -0.004979
# 2010-01-13  0.004878 -0.007586 -0.004003
# 2010-01-14 -0.001133 -0.003132  0.000144
# 2010-01-15 -0.001458 -0.004023 -0.008180
# 2010-01-19  0.011032  0.005680  0.002315
# 2010-01-20 -0.020218 -0.019202 -0.017901
# 2010-01-21 -0.024402 -0.024440 -0.019550
# 2010-01-22 -0.028538 -0.021642 -0.008996
# 2010-01-25  0.011751 -0.000536 -0.003782
# 2010-01-26 -0.001025 -0.005366  0.001063
# 2010-01-27 -0.007352 -0.006069 -0.005764
# 2010-01-28 -0.012573 -0.006242 -0.008850
# 2010-01-29 -0.021106 -0.015292 -0.008159
# 2010-02-01  0.019779  0.020244  0.027161
# 2010-02-02 -0.030928  0.011824  0.011786
# ...

# %%
# %matplotlib inline
prices.plot()

# %%
# To plot the corelation
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr = returns.dropna().corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, cmap = sns.diverging_palette(256,0,sep=80,n=7,as_cmap=False),annot = False, mask = mask)
